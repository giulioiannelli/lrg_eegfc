# %%
from lrgsglib import *
#
move_to_rootf(pathname='lrg_eegfc')
#
from src.lrg_eegfc import *
# Out:
# Current working directory: /home/opisthofulax/Documents/research+/brain_network/lrg_eegfc

# %%
data_dict = {}
int_label_pos_map = {}

for pat in patients_list:
    data_dict[pat] = {}
    #
    patnum = int(pat.split('_')[-1])
    patpath = mat_path / pat
    #
    ch_dat = pd.read_csv(patpath / f'Implant_pat_{patnum}.csv')
    ch_names = pd.read_csv(patpath / 'channel_labels.csv')
    #
    int_label_pos_map[pat] = ch_names.merge(ch_dat,on='label', how='left')
    df = int_label_pos_map[pat][['x', 'y', 'z']]
    df = df.apply(lambda s: s.str.replace(',', '.', regex=False).astype(float))
    #
    for phase in phase_labels:
        data_dict[pat][phase] = {}
        tmp_mat = load_mat_pat_data(pat, phase, mat_path)
        #
        data_dict[pat][phase]['data'] = tmp_mat['Data']
        tmp_shape = tmp_mat['Data'].shape
        #
        if tmp_shape[0] > tmp_shape[1]:
            data_dict[pat][phase]['data'] = data_dict[pat][phase]['data'].T
        try:
            # Check if 'Parameters' is in the loaded data
            for param in tmp_mat['Parameters'].dtype.names:
                if param in param_keys_list:
                    data_dict[pat][phase][param] = tmp_mat['Parameters'][param][0][0][0][0]
        except:
            print(f'No parameters found for {pat} {phase}', end='\r', flush=True)
            continue

# %% [markdown]
# ### Split in time windows

# %%
patient = 'Pat_02'
phase = 'rsPre'
#
corr_net_filt = dict(threshold=0)
#
data_pat_phase = data_dict[patient][phase]
data_pat_phase_ts = data_pat_phase['data']
fs = data_pat_phase['fs']
filter_order = data_pat_phase['filter_order']
#
n_intervals = 100
interval_length = int(data_pat_phase_ts.shape[1] // n_intervals)
n_intervals, interval_length
# Out:
# (100, 13232)

# %%
corr_mat_band_tw = {}
for band_name, (low, high) in tqdm(BRAIN_BANDS.items()):
    corr_mat_band_tw[band_name] = {}
    for i in range(n_intervals):
        start = i * interval_length
        end = (i + 1) * interval_length
        interval_data = data_pat_phase_ts[:, start:end]
        filter_data = bandpass_sos(interval_data, low, high, fs, 3)
        corr_mat = build_corr_network(filter_data, **corr_net_filt)
        corr_mat_band_tw[band_name][i] = corr_mat
# Out:
# 100%|██████████| 6/6 [00:18<00:00,  3.11s/it]

# %%
corr_nets = {band_name: {i: nx.from_numpy_array(corr_mat_band_tw[band_name][i]) for i in range(n_intervals)} for band_name, (low, high) in tqdm(BRAIN_BANDS.items())}

corr_nets_th = {'delta': {i: threshold_graph(G0, 0.9) for i, G0 in corr_nets['delta'].items()}}
clear_output()
# Out:
# 100%|██████████| 6/6 [00:05<00:00,  1.05it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 70.49it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 80.18it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 61.40it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 62.50it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 45.66it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 72.88it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 66.15it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 78.64it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 43.24it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 63.85it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 80.59it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 67.90it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 48.63it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 70.97it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 65.29it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 83.68it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 63.71it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 45.43it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 80.88it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 73.70it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 81.64it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 44.49it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 59.28it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 71.02it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 74.45it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 71.16it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 46.01it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 56.85it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 78.51it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 71.51it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 41.43it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 51.95it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 55.58it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 77.99it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 41.97it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 57.84it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 66.82it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 61.09it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 49.54it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 67.33it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 84.79it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 62.75it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 69.96it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 42.20it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 55.14it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 65.56it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 52.20it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 46.03it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 82.17it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 62.23it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 69.94it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 83.85it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 49.02it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 74.23it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 82.65it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 70.58it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 50.48it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 72.95it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 78.85it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 76.77it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 43.78it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 73.80it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 74.71it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 72.56it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 87.06it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 48.94it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 73.80it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 71.72it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 72.10it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 43.21it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 62.55it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 76.16it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 84.52it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 82.14it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 49.11it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 65.58it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 70.89it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 75.88it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 43.35it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 54.39it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 63.38it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 67.56it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 46.30it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 66.56it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 66.45it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 68.82it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 75.30it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 48.76it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 71.01it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 78.87it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 75.22it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:02<00:00, 46.17it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 70.73it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 74.40it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 77.79it/s]
# Computing threshold stats: 100%|██████████| 117/117 [00:01<00:00, 74.97it/s]
# Computing threshold stats:   7%|▋         | 8/117 [00:00<00:01, 71.36it/s]

# %%
# 1. collect your data pairs (t1, dS1) for each time step into a list
data_list = []
for i, arr in corr_nets_th['delta'].items():
    Gcc, _ = get_giant_component_leftoff(arr[1])
    _, dS1, _, t1 = entropy(Gcc)
    data_list.append((t1[1:], dS1))
# Out:
# /home/opisthofulax/Documents/research+/brain_network/lrg_eegfc/lrgsglib/src/lrgsglib/utils/lrg/infocomm.py:91: RuntimeWarning: divide by zero encountered in log
#   S[i] = -np.nansum(rho * np.log(rho)) / np.log(N)
# /home/opisthofulax/Documents/research+/brain_network/lrg_eegfc/lrgsglib/src/lrgsglib/utils/lrg/infocomm.py:91: RuntimeWarning: invalid value encountered in multiply
#   S[i] = -np.nansum(rho * np.log(rho)) / np.log(N)

# %%
fig, ax = plt.subplots(8, len(corr_nets_th['delta'])//8, figsize=(20, 10))
ax = ax.flatten()
for i, arr in corr_nets_th['delta'].items():
    if i >= len(corr_nets_th['delta'])//8*8:
        break
    ax[i].set_title(i)
    Gcc, removed_nodes = get_giant_component_leftoff(arr[1])
    pos = nx.spring_layout(Gcc, seed=42)
    labeldict = {k: v for k, v in int_label_pos_map[pat]['label'].to_dict().items() if k not in removed_nodes}
    colorlist = [v for k,v in labeldict.items()]
    values = list(map(int_label_pos_map[pat]['label'].to_dict().get, removed_nodes))
    # print(values)
    # 1. extract only the letters you actually have
    letters = sorted({label[0].upper() for label in labeldict.values()})

    # 2. spread them evenly around the hue circle
    hues = [i / len(letters) for i in range(len(letters))]

    # 3. build your base‐color map
    base_colors = {
        letter: mcolors.hsv_to_rgb((hue, 1, 1))
        for letter, hue in zip(letters, hues)
    }

    def node_color(label: str) -> str:
        """
        label: e.g. 'A2', 'C10', etc.
        returns: hex color string where the base hue is set by the first letter
                and the intensity (1–10) modulates saturation towards white.
        """
        letter = label[0].upper()
        intensity = int(label[1:]) % 10 or 10
        t = intensity / 10
        rgb = base_colors.get(letter, (0.5, 0.5, 0.5))
        mixed = tuple((1 - t) + c * t for c in rgb)  # blend with white
        return mcolors.to_hex(mixed)


    colors = {node: node_color(node) for node in colorlist}
    cl= list(colors.values())

    # nx.draw(Gcc, pos, ax=ax[i], node_color=cl, with_labels=True, node_size=50, font_size=8, labels=labeldict)
    # ax[i].set_xticks([])
    # ax[i].set_yticks([])
    [Sm1, dS1, VarL1, t1] = entropy(Gcc)
    ax[i].plot(t1[1:], dS1)
    ax[i].set_xscale('log')
fig.tight_layout()
# Out:
# /home/opisthofulax/Documents/research+/brain_network/lrg_eegfc/lrgsglib/src/lrgsglib/utils/lrg/infocomm.py:91: RuntimeWarning: divide by zero encountered in log
#   S[i] = -np.nansum(rho * np.log(rho)) / np.log(N)
# /home/opisthofulax/Documents/research+/brain_network/lrg_eegfc/lrgsglib/src/lrgsglib/utils/lrg/infocomm.py:91: RuntimeWarning: invalid value encountered in multiply
#   S[i] = -np.nansum(rho * np.log(rho)) / np.log(N)
